# %% [markdown]
# # 04. Model Training, 2026 Holdout Evaluation & Retraining
# Benchmarking 7 models on unseen 2026 data and retraining the final forecaster up to September 19, 2026.

# %%
import sys, os, pandas as pd
sys.path.insert(0, os.path.abspath('..'))
from src.train import train_and_evaluate_all

res_df, bundle = train_and_evaluate_all()
print('2026 Test Period Results:')
print(res_df)

# %% [markdown]
# # 03. Time-Series Feature Engineering (Zero-Leakage)
# Constructing lag features, rolling statistics, calendar indicators, and momentum features strictly backward-looking.

# %%
import sys, os, pandas as pd
sys.path.insert(0, os.path.abspath('..'))
from src.preprocessing import load_and_preprocess
from src.feature_engineering import create_features, FEATURE_COLUMNS

df = load_and_preprocess(save_processed=False)
feat_df = create_features(df, drop_na=True)
print(f'Feature columns count: {len(FEATURE_COLUMNS)}')
print('Features:', FEATURE_COLUMNS)
feat_df[FEATURE_COLUMNS].head()

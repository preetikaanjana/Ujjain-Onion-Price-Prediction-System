# %% [markdown]
# # 01. Data Collection & API Retrieval (AGMARKNET 2.0)
# **Project:** Ujjain Onion Price Prediction System (2024?2026)
# **Source:** Directorate of Marketing & Inspection (DMI) / AGMARKNET 2.0
# This notebook demonstrates reproducible ingestion of official government mandi records.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from src.data_collection import load_raw_data, summarize_dataset

df = load_raw_data()
summary = summarize_dataset(df)
print('Dataset Verification Summary:')
for k, v in summary.items():
    print(f'  {k}: {v}')
df.head()
